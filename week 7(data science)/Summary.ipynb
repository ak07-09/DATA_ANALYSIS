# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# ### Types of EDA
#
# 1. Descriptive
#
# 2. Diagnostic
#
# 3. Predictive
#
# 4. Prescriptive

# %% [markdown]
# ## Types of Data
# ### Categorical Data
#
# 1. Nominal
#
# 2. Ordinal
#
# ### Numerical Data
#
# 1. Discrete
#
# 2. Continuous

# %% [markdown]
# ### Sampling Techniques
#
# 1. Random Sampling
#
# 2. Systematic Sampling
#
# 3. Stratified Sampling
#
# 4. Cluster Sampling

# %% [markdown]
# ### Types of Encoding
#
# 1. Label Encoding
#
# 2. One-Hot Encoding

# %% [markdown]
# ### Types of Statistics
#
# 1. Descriptive Statistics
#
# 2. Inferential Statistics

# %% [markdown]
# ### Steps of Data Analysis
#
# 1. Importing Libraries
#
# 2. Data Loading
#
# 3. Data Cleaning
#
# 4. Data Transformation
#
# 5. Data Exploration
#
# 6. Data Analysis
#
# 7. Data Visualization
#
# 8. Insights and Conclusion

# %% [markdown]
# Z-score and Z-Test are Different
#
# z-score is used to identify the outlier using xi-mean/std deviation
#
# Z-test is used to compare the mean of two population when the variance is known and sample size

# %% [markdown]
# Types Of Outliers
#
# --- outliers due to variability in data or not due to experimental errors.
#
# --- outiers due to experimental can be handled by only removing them.

# %% [markdown]
# ##### -- We can make the outliers less significant by applying transformations like log transformation, square root transformation etc. --
# #### Handling outliers:
# 1. Remove outliers
# 2. Transform data:
#     - Log Transformation - np.[fun]
#     - Power Transformation - sklearn :
#           1. Box - cox
#           2. yeo - johnson

# %% [markdown]
# -- Whenever you want to analyse the two categorical columns, use Chi-Square test
#
# -- Whenever you want to analyse the two numerical columns, use Anova test
