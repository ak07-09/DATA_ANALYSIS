# %% [markdown]
# # GOAL:
#
# ## Performing an end-to-end analysis on the World Happiness Report 2023 dataset.

# %% [markdown]
# ## 1. Why This Project?
#
# 1. Explore key factors related to happiness scores by country
#
# 2. Visualize distributions and correlations of indicators
#
# 3. Draw insights into factors affecting global happiness

# %% [markdown]
# ## 2. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
